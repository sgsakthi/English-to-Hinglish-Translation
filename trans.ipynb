# %%
# Full Translation to Hindi

from transformers import MarianMTModel, MarianTokenizer

# Define source language and target language
src_lang = 'en'
tgt_lang = 'hi'

# Load the tokenizer and model
model_name = f'Helsinki-NLP/opus-mt-{src_lang}-{tgt_lang}'
model = MarianMTModel.from_pretrained(model_name)
tokenizer = MarianTokenizer.from_pretrained(model_name)

# Translate
def translate(text):
    # Tokenize the text
    tokenized_text = tokenizer.encode(text, return_tensors="pt")
    
    # Get the translation
    translation = model.generate(tokenized_text)
    
    # Decode and return the translated text
    translated_text = tokenizer.decode(translation[0], skip_special_tokens=True)
    return translated_text

# Use the function
english_text = "I had about a 30 minute demo just using this new headset"
hindi_translation = translate(english_text)
print(hindi_translation)
# Out:
# a:\Anaconda\envs\voice-text-translate\lib\site-packages\transformers\generation\utils.py:1369: UserWarning: Using `max_length`'s default (512) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# मैं 30 मिनट डेमो था सिर्फ इस नए सिरसेट का इस्तेमाल

# %% [markdown]
# To make changes to sentences like the one you provided you'd need a model specially trained on it. But, and it's a big but, building something that can rearrange or translate any sentence you throw at it is pretty tricky. You'd need tons of data and some pretty advanced tech. For Hind it's lack to my research

# %% [markdown]
# This is my Manual method but not the effective one when working with large number of data

# %% [markdown]
# #### Method 1

# %%
# Desired output: मुझे सिर्फ ३० minute का demo मिला था इस नये headset का इस्तेमाल करने के लिए

# %%
# Recreate the dictionary for word to word translation for the given sentence.
translation_map = {
    "I": "मुझे",
    "had": "मिला था",
    "about": "सिर्फ",
    "a": "का",
    "30": "३०",
    "minute": "minute",
    "demo": "demo",
    "just": "",
    "using": "इस्तेमाल करने के लिए",
    "this": "इस",
    "new": "नये",
    "headset": "headset"
}

# Manually reordering and constructing the sentence to match the desired translation
desired_translation = "{} {} {} {} {} {} {} {} {} {} {}".format(
    translation_map["I"],
    translation_map["about"],
    translation_map["30"],
    translation_map["minute"],
    translation_map["a"],
    translation_map["demo"],
    translation_map["had"],
    translation_map["this"],
    translation_map["new"],
    translation_map["headset"],
    translation_map["using"]
)

desired_translation
# Out:
# 'मुझे सिर्फ ३० minute का demo मिला था इस नये headset इस्तेमाल करने के लिए'
